# %%
import os
os.chdir("/kaggle/working")
# !rm -rf reusableCodebook
# !git clone https://github.com/shashwatsaket46/reusableCodebook.git
# %cd reusableCodebook
# Out:
# Cloning into 'reusableCodebook'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (166/166), done.
# remote: Total 230 (delta 130), reused 157 (delta 61), pack-reused 0 (from 0)
# Receiving objects: 100% (230/230), 65.38 KiB | 10.90 MiB/s, done.
# Resolving deltas: 100% (130/130), done.
# /kaggle/working/reusableCodebook

# %%
! bash run_all.sh
# Out:
# Datasets: glove200_100k openai1536 openai3072
# Logs:     /kaggle/working/reusableCodebook/results/logs/
#
# [1/7] Setting up upstream repo + dependencies
#   cloning Extended-RaBitQ...
# Cloning into '/kaggle/working/reusableCodebook/third_party/Extended-RaBitQ'...
#   vendoring Eigen 3.4.0...
#   vendoring hnswlib...
# Cloning into 'hnswlib_src'...
#   applying overrides from cpp/overrides/...
#     '/kaggle/working/reusableCodebook/cpp/overrides/./inc/index/HASearcher.hpp' -> '/kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/./inc/index/HASearcher.hpp'
#     '/kaggle/working/reusableCodebook/cpp/overrides/./inc/index/IVF.hpp' -> '/kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/./inc/index/IVF.hpp'
#     '/kaggle/working/reusableCodebook/cpp/overrides/./inc/index/Quantizer.hpp' -> '/kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/./inc/index/Quantizer.hpp'
#     '/kaggle/working/reusableCodebook/cpp/overrides/./inc/index/Searcher.hpp' -> '/kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/./inc/index/Searcher.hpp'
#     '/kaggle/working/reusableCodebook/cpp/overrides/./inc/utils/space.hpp' -> '/kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/./inc/utils/space.hpp'
#     '/kaggle/working/reusableCodebook/cpp/overrides/./src/create_index.cpp' -> '/kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/./src/create_index.cpp'
#     '/kaggle/working/reusableCodebook/cpp/overrides/./src/test_search.cpp' -> '/kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/./src/test_search.cpp'
# generated /kaggle/working/reusableCodebook/cpp/experiment_config.hpp
#   cleaning old build artifacts...
# [ 25%] Building CXX object src/CMakeFiles/create_index.dir/create_index.cpp.o
# [ 50%] Building CXX object src/CMakeFiles/test_search.dir/test_search.cpp.o
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/HASearcher.hpp:10,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:14,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:10:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/fastscan/FastScan.hpp: In function ‘uint32_t accumulate_one_block_high_acc(const uint8_t*, const uint8_t*, const float*, float, float, float, int, float*, float*, float, float, size_t)’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/fastscan/FastScan.hpp:222:25: warning: unused parameter ‘low_dist’ [-Wunused-parameter]
#   222 |     float* __restrict__ low_dist,
#       |     ~~~~~~~~~~~~~~~~~~~~^~~~~~~~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:11,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:16,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:10:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswlib.h: In member function ‘virtual bool hnswlib::BaseFilterFunctor::operator()(hnswlib::labeltype)’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswlib.h:130:48: warning: unused parameter ‘id’ [-Wunused-parameter]
#   130 |     virtual bool operator()(hnswlib::labeltype id) { return true; }
#       |                             ~~~~~~~~~~~~~~~~~~~^~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswlib.h:225,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:11,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:16,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:10:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/space_ip.h: In function ‘float hnswlib::InnerProductSIMD16ExtAVX512(const void*, const void*, const void*)’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/space_ip.h:148:28: warning: unused variable ‘TmpRes’ [-Wunused-variable]
#   148 |     float PORTABLE_ALIGN64 TmpRes[16];
#       |                            ^~~~~~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/HASearcher.hpp:10,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:14,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp:6:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/fastscan/FastScan.hpp: In function ‘uint32_t accumulate_one_block_high_acc(const uint8_t*, const uint8_t*, const float*, float, float, float, int, float*, float*, float, float, size_t)’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/fastscan/FastScan.hpp:222:25: warning: unused parameter ‘low_dist’ [-Wunused-parameter]
#   222 |     float* __restrict__ low_dist,
#       |     ~~~~~~~~~~~~~~~~~~~~^~~~~~~~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:11,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:16,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp:6:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswlib.h: In member function ‘virtual bool hnswlib::BaseFilterFunctor::operator()(hnswlib::labeltype)’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswlib.h:130:48: warning: unused parameter ‘id’ [-Wunused-parameter]
#   130 |     virtual bool operator()(hnswlib::labeltype id) { return true; }
#       |                             ~~~~~~~~~~~~~~~~~~~^~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswlib.h:225,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:11,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:16,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp:6:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/space_ip.h: In function ‘float hnswlib::InnerProductSIMD16ExtAVX512(const void*, const void*, const void*)’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/space_ip.h:148:28: warning: unused variable ‘TmpRes’ [-Wunused-variable]
#   148 |     float PORTABLE_ALIGN64 TmpRes[16];
#       |                            ^~~~~~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:10:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp: In member function ‘void IVF::search(const float*, const float*, size_t, size_t, PID*) const’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:297:31: warning: unused parameter ‘data’ [-Wunused-parameter]
#   297 |     const float* __restrict__ data,
#       |     ~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp: In function ‘int main(int, char**)’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:20:14: warning: unused parameter ‘argc’ [-Wunused-parameter]
#    20 | int main(int argc, char* argv[]) {
#       |          ~~~~^~~~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp:6:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp: In member function ‘void IVF::search(const float*, const float*, size_t, size_t, PID*) const’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:297:31: warning: unused parameter ‘data’ [-Wunused-parameter]
#   297 |     const float* __restrict__ data,
#       |     ~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp: In function ‘int main(int, char**)’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp:10:14: warning: unused parameter ‘argc’ [-Wunused-parameter]
#    10 | int main(int argc, char* argv[]) {
#       |          ~~~~^~~~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswlib.h:228,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:11,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:16,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:10:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h: In instantiation of ‘std::priority_queue<std::pair<dist_t, long unsigned int> > hnswlib::HierarchicalNSW<dist_t>::searchKnn(const void*, size_t, hnswlib::BaseFilterFunctor*) const [with dist_t = float; typename std::vector<std::pair<dist_t, long unsigned int> >::value_type = std::pair<float, long unsigned int>; size_t = long unsigned int]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:108:32:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:1291:30: warning: comparison of unsigned expression in ‘< 0’ is always false [-Wtype-limits]
#  1291 |                     if (cand < 0 || cand > max_elements_)
#       |                         ~~~~~^~~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswlib.h:228,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:11,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:16,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp:6:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h: In instantiation of ‘std::priority_queue<std::pair<dist_t, long unsigned int> > hnswlib::HierarchicalNSW<dist_t>::searchKnn(const void*, size_t, hnswlib::BaseFilterFunctor*) const [with dist_t = float; typename std::vector<std::pair<dist_t, long unsigned int> >::value_type = std::pair<float, long unsigned int>; size_t = long unsigned int]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:108:32:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:1291:30: warning: comparison of unsigned expression in ‘< 0’ is always false [-Wtype-limits]
#  1291 |                     if (cand < 0 || cand > max_elements_)
#       |                         ~~~~~^~~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:21,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:10:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/utils/IO.hpp: In instantiation of ‘void load_vecs(const char*, M&) [with T = float; M = Eigen::Matrix<float, -1, -1, 1>]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:42:34:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/utils/IO.hpp:60:8: warning: unused variable ‘ptr’ [-Wunused-variable]
#    60 |     T* ptr;
#       |        ^~~
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/utils/IO.hpp: In instantiation of ‘void load_vecs(const char*, M&) [with T = unsigned int; M = Eigen::Matrix<unsigned int, -1, -1, 1>]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:44:31:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/utils/IO.hpp:60:8: warning: unused variable ‘ptr’ [-Wunused-variable]
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Rotator.hpp:7,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Quantizer.hpp:14,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Cluster.hpp:11,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:13,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:10:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/utils/tools.hpp: In instantiation of ‘std::vector<_Tp> horizontal_avg(const std::vector<std::vector<_Tp> >&) [with T = float]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:135:34:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/utils/tools.hpp:58:16: warning: unused variable ‘row’ [-Wunused-variable]
#    58 |     for (auto& row : data) {
#       |                ^~~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:21,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp:6:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/utils/IO.hpp: In instantiation of ‘void load_vecs(const char*, M&) [with T = float; M = Eigen::Matrix<float, -1, -1, 1>]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp:33:34:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/utils/IO.hpp:60:8: warning: unused variable ‘ptr’ [-Wunused-variable]
#    60 |     T* ptr;
#       |        ^~~
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/utils/IO.hpp: In instantiation of ‘void load_vecs(const char*, M&) [with T = unsigned int; M = Eigen::Matrix<unsigned int, -1, -1, 1>]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp:35:31:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/utils/IO.hpp:60:8: warning: unused variable ‘ptr’ [-Wunused-variable]
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswlib.h:228,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:11,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:16,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/test_search.cpp:10:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h: In instantiation of ‘hnswlib::tableint hnswlib::HierarchicalNSW<dist_t>::addPoint(const void*, hnswlib::labeltype, int) [with dist_t = float; hnswlib::tableint = unsigned int; hnswlib::labeltype = long unsigned int]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:961:21:   required from ‘void hnswlib::HierarchicalNSW<dist_t>::addPoint(const void*, hnswlib::labeltype, bool) [with dist_t = float; hnswlib::labeltype = long unsigned int]’
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:94:31:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:1227:38: warning: comparison of unsigned expression in ‘< 0’ is always false [-Wtype-limits]
#  1227 |                             if (cand < 0 || cand > max_elements_)
#       |                                 ~~~~~^~~
# In file included from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswlib.h:228,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:11,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/IVF.hpp:16,
#                  from /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/src/create_index.cpp:6:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h: In instantiation of ‘hnswlib::tableint hnswlib::HierarchicalNSW<dist_t>::addPoint(const void*, hnswlib::labeltype, int) [with dist_t = float; hnswlib::tableint = unsigned int; hnswlib::labeltype = long unsigned int]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:961:21:   required from ‘void hnswlib::HierarchicalNSW<dist_t>::addPoint(const void*, hnswlib::labeltype, bool) [with dist_t = float; hnswlib::labeltype = long unsigned int]’
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:94:31:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:1227:38: warning: comparison of unsigned expression in ‘< 0’ is always false [-Wtype-limits]
#  1227 |                             if (cand < 0 || cand > max_elements_)
#       |                                 ~~~~~^~~
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h: In instantiation of ‘hnswlib::tableint hnswlib::HierarchicalNSW<dist_t>::mutuallyConnectNewElement(const void*, hnswlib::tableint, std::priority_queue<std::pair<dist_t, unsigned int>, std::vector<std::pair<dist_t, unsigned int> >, hnswlib::HierarchicalNSW<dist_t>::CompareByFirst>&, int, bool) [with dist_t = float; hnswlib::tableint = unsigned int]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:1252:27:   required from ‘hnswlib::tableint hnswlib::HierarchicalNSW<dist_t>::addPoint(const void*, hnswlib::labeltype, int) [with dist_t = float; hnswlib::tableint = unsigned int; hnswlib::labeltype = long unsigned int]’
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:961:21:   required from ‘void hnswlib::HierarchicalNSW<dist_t>::addPoint(const void*, hnswlib::labeltype, bool) [with dist_t = float; hnswlib::labeltype = long unsigned int]’
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:94:31:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:507:21: warning: unused parameter ‘data_point’ [-Wunused-parameter]
#   507 |         const void *data_point,
#       |         ~~~~~~~~~~~~^~~~~~~~~~
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h: In instantiation of ‘hnswlib::tableint hnswlib::HierarchicalNSW<dist_t>::mutuallyConnectNewElement(const void*, hnswlib::tableint, std::priority_queue<std::pair<dist_t, unsigned int>, std::vector<std::pair<dist_t, unsigned int> >, hnswlib::HierarchicalNSW<dist_t>::CompareByFirst>&, int, bool) [with dist_t = float; hnswlib::tableint = unsigned int]’:
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:1252:27:   required from ‘hnswlib::tableint hnswlib::HierarchicalNSW<dist_t>::addPoint(const void*, hnswlib::labeltype, int) [with dist_t = float; hnswlib::tableint = unsigned int; hnswlib::labeltype = long unsigned int]’
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:961:21:   required from ‘void hnswlib::HierarchicalNSW<dist_t>::addPoint(const void*, hnswlib::labeltype, bool) [with dist_t = float; hnswlib::labeltype = long unsigned int]’
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/index/Initializer.hpp:94:31:   required from here
# /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/inc/third/hnswlib/hnswalg.h:507:21: warning: unused parameter ‘data_point’ [-Wunused-parameter]
#   507 |         const void *data_point,
#       |         ~~~~~~~~~~~~^~~~~~~~~~
# [ 75%] Linking CXX executable /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/bin/create_index
# [ 75%] Built target create_index
# [100%] Linking CXX executable /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/bin/test_search
# [100%] Built target test_search
#   binaries:
# total 568K
# -rwxr-xr-x 1 root root 273K Apr 26 06:00 create_index
# -rwxr-xr-x 1 root root 290K Apr 26 06:00 test_search
# [2/7] Preparing datasets
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [glove200_100k] preparing ...
#   copying from /kaggle/input/datasets/shashwatsaket/glove-200/glove-200-angular.hdf5 ...
#   building GT (FlatIP) for 10000 queries x 100000 base ...
#   done. base (100000, 200) | query (10000, 200) | GT (10000, 32)
# [openai1536] preparing ... (streaming from HF)
#   10000/101000
#   20000/101000
#   30000/101000
#   40000/101000
#   50000/101000
#   60000/101000
#   70000/101000
#   80000/101000
#   90000/101000
#   100000/101000
#   building GT (FlatIP) for 1000 queries x 100000 base ...
#   done. base (100000, 1536) | query (1000, 1536) | GT (1000, 32)
# [openai3072] preparing ... (streaming from HF)
#   10000/101000
#   20000/101000
#   30000/101000
#   40000/101000
#   50000/101000
#   60000/101000
#   70000/101000
#   80000/101000
#   90000/101000
#   100000/101000
#   building GT (FlatIP) for 1000 queries x 100000 base ...
#   done. base (100000, 3072) | query (1000, 3072) | GT (1000, 32)
#
# all datasets ready in /kaggle/working/reusableCodebook/third_party/Extended-RaBitQ/data
# [3/7] IVF clustering
#   [glove200_100k] running k-means with K=256 ...
# Sampling a subset of 65536 / 100000 for training
# Clustering 65536 points in 200D to 256 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.06 s
# Reading data/glove200_100k/glove200_100k_base.fvecs1822.4 imbalance=1.131 nsplit=0
# Reading File - data/glove200_100k/glove200_100k_base.fvecs
# 	data/glove200_100k/glove200_100k_base.fvecs readed
#   N=100000  D=200  K=256
# Running k-means ...
# Writing File - data/glove200_100k/glove200_100k_centroid_256.fvecs
# 	data/glove200_100k/glove200_100k_centroid_256.fvecs wrote
# Writing File - data/glove200_100k/glove200_100k_cluster_id_256.ivecs
# 	data/glove200_100k/glove200_100k_cluster_id_256.ivecs wrote
# Writing File - data/glove200_100k/glove200_100k_dist_to_centroid_256.fvecs
# 	data/glove200_100k/glove200_100k_dist_to_centroid_256.fvecs wrote
# Done.
#
#   [openai1536] running k-means with K=256 ...
# Sampling a subset of 65536 / 100000 for training
# Clustering 65536 points in 1536D to 256 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.40 s
# Reading data/openai1536/openai1536_base.fvecsective=47814.5 imbalance=1.162 nsplit=0
# Reading File - data/openai1536/openai1536_base.fvecs
# 	data/openai1536/openai1536_base.fvecs readed
#   N=100000  D=1536  K=256
# Running k-means ...
# Writing File - data/openai1536/openai1536_centroid_256.fvecs
# 	data/openai1536/openai1536_centroid_256.fvecs wrote
# Writing File - data/openai1536/openai1536_cluster_id_256.ivecs
# 	data/openai1536/openai1536_cluster_id_256.ivecs wrote
# Writing File - data/openai1536/openai1536_dist_to_centroid_256.fvecs
# 	data/openai1536/openai1536_dist_to_centroid_256.fvecs wrote
# Done.
#
#   [openai3072] running k-means with K=256 ...
# Sampling a subset of 65536 / 100000 for training
# Clustering 65536 points in 3072D to 256 clusters, redo 1 times, 25 iterations
#   Preprocessing in 0.80 s
# Reading data/openai3072/openai3072_base.fvecsective=48958 imbalance=1.165 nsplit=0
# Reading File - data/openai3072/openai3072_base.fvecs
# 	data/openai3072/openai3072_base.fvecs readed
#   N=100000  D=3072  K=256
# Running k-means ...
# Writing File - data/openai3072/openai3072_centroid_256.fvecs
# 	data/openai3072/openai3072_centroid_256.fvecs wrote
# Writing File - data/openai3072/openai3072_cluster_id_256.ivecs
# 	data/openai3072/openai3072_cluster_id_256.ivecs wrote
# Writing File - data/openai3072/openai3072_dist_to_centroid_256.fvecs
# 	data/openai3072/openai3072_dist_to_centroid_256.fvecs wrote
# Done.
#
# [4/7] Building Extended-RaBitQ indexes
# === create_index glove200_100k 256 2 ===
# File ../data/glove200_100k/glove200_100k_base.fvecs loaded
# Rows 100000 Cols 200
# File ../data/glove200_100k/glove200_100k_centroid_256.fvecs loaded
# Rows 256 Cols 200
# File ../data/glove200_100k/glove200_100k_cluster_id_256.ivecs loaded
# Rows 100000 Cols 1
# data loaded
# 	N: 100000
# 	DIM: 200
# Start IVF construction...
# 	Loading clustering information...
# Allocating memory for IVF...
# ivf constructed
# Indexing time: 0.0195667miniutes
# === create_index glove200_100k 256 4 ===
# File ../data/glove200_100k/glove200_100k_base.fvecs loaded
# Rows 100000 Cols 200
# File ../data/glove200_100k/glove200_100k_centroid_256.fvecs loaded
# Rows 256 Cols 200
# File ../data/glove200_100k/glove200_100k_cluster_id_256.ivecs loaded
# Rows 100000 Cols 1
# data loaded
# 	N: 100000
# 	DIM: 200
# Start IVF construction...
# 	Loading clustering information...
# Allocating memory for IVF...
# ivf constructed
# Indexing time: 0.0536667miniutes
# === create_index openai1536 256 2 ===
# File ../data/openai1536/openai1536_base.fvecs loaded
# Rows 100000 Cols 1536
# File ../data/openai1536/openai1536_centroid_256.fvecs loaded
# Rows 256 Cols 1536
# File ../data/openai1536/openai1536_cluster_id_256.ivecs loaded
# Rows 100000 Cols 1
# data loaded
# 	N: 100000
# 	DIM: 1536
# Start IVF construction...
# 	Loading clustering information...
# Allocating memory for IVF...
# ivf constructed
# Indexing time: 0.180617miniutes
# === create_index openai1536 256 4 ===
# File ../data/openai1536/openai1536_base.fvecs loaded
# Rows 100000 Cols 1536
# File ../data/openai1536/openai1536_centroid_256.fvecs loaded
# Rows 256 Cols 1536
# File ../data/openai1536/openai1536_cluster_id_256.ivecs loaded
# Rows 100000 Cols 1
# data loaded
# 	N: 100000
# 	DIM: 1536
# Start IVF construction...
# 	Loading clustering information...
# Allocating memory for IVF...
# ivf constructed
# Indexing time: 0.39995miniutes
# === create_index openai3072 256 2 ===
# File ../data/openai3072/openai3072_base.fvecs loaded
# Rows 100000 Cols 3072
# File ../data/openai3072/openai3072_centroid_256.fvecs loaded
# Rows 256 Cols 3072
# File ../data/openai3072/openai3072_cluster_id_256.ivecs loaded
# Rows 100000 Cols 1
# data loaded
# 	N: 100000
# 	DIM: 3072
# Start IVF construction...
# 	Loading clustering information...
# Allocating memory for IVF...
# ivf constructed
# Indexing time: 0.52255miniutes
# === create_index openai3072 256 4 ===
# File ../data/openai3072/openai3072_base.fvecs loaded
# Rows 100000 Cols 3072
# File ../data/openai3072/openai3072_centroid_256.fvecs loaded
# Rows 256 Cols 3072
# File ../data/openai3072/openai3072_cluster_id_256.ivecs loaded
# Rows 100000 Cols 1
# data loaded
# 	N: 100000
# 	DIM: 3072
# Start IVF construction...
# 	Loading clustering information...
# Allocating memory for IVF...
# ivf constructed
# Indexing time: 0.993233miniutes
# [5/7] Running test_search
# === test_search glove200_100k 2 ===
# File ../data/glove200_100k/glove200_100k_base.fvecs loaded
# Rows 100000 Cols 200
# File ../data/glove200_100k/glove200_100k_query.fvecs loaded
# Rows 10000 Cols 200
# File ../data/glove200_100k/glove200_100k_groundtruth.ivecs loaded
# Rows 10000 Cols 32
# data loaded
# 	N: 100000
# 	DIM: 200
# query loaded
# 	NQ: 10000
# Loading IVF...
# 	Loading meta data...
# Allocating memory for IVF...
# Index loaded
# EVAL bits=2 nprobe=256 k=1 recall=0.6529
# EVAL bits=2 nprobe=256 k=2 recall=0.8032
# EVAL bits=2 nprobe=256 k=4 recall=0.9071
# EVAL bits=2 nprobe=256 k=8 recall=0.9625
# EVAL bits=2 nprobe=256 k=16 recall=0.9875
# EVAL bits=2 nprobe=256 k=32 recall=0.9962
#
#   EVAL lines: 6
# === test_search glove200_100k 4 ===
# File ../data/glove200_100k/glove200_100k_base.fvecs loaded
# Rows 100000 Cols 200
# File ../data/glove200_100k/glove200_100k_query.fvecs loaded
# Rows 10000 Cols 200
# File ../data/glove200_100k/glove200_100k_groundtruth.ivecs loaded
# Rows 10000 Cols 32
# data loaded
# 	N: 100000
# 	DIM: 200
# query loaded
# 	NQ: 10000
# Loading IVF...
# 	Loading meta data...
# Allocating memory for IVF...
# Index loaded
# EVAL bits=4 nprobe=256 k=1 recall=0.8803
# EVAL bits=4 nprobe=256 k=2 recall=0.9731
# EVAL bits=4 nprobe=256 k=4 recall=0.9966
# EVAL bits=4 nprobe=256 k=8 recall=0.9998
# EVAL bits=4 nprobe=256 k=16 recall=0.9999
# EVAL bits=4 nprobe=256 k=32 recall=0.9999
#
#   EVAL lines: 6
# === test_search openai1536 2 ===
# File ../data/openai1536/openai1536_base.fvecs loaded
# Rows 100000 Cols 1536
# File ../data/openai1536/openai1536_query.fvecs loaded
# Rows 1000 Cols 1536
# File ../data/openai1536/openai1536_groundtruth.ivecs loaded
# Rows 1000 Cols 32
# data loaded
# 	N: 100000
# 	DIM: 1536
# query loaded
# 	NQ: 1000
# Loading IVF...
# 	Loading meta data...
# Allocating memory for IVF...
# Index loaded
# EVAL bits=2 nprobe=256 k=1 recall=0.893
# EVAL bits=2 nprobe=256 k=2 recall=0.984
# EVAL bits=2 nprobe=256 k=4 recall=0.999
# EVAL bits=2 nprobe=256 k=8 recall=1
# EVAL bits=2 nprobe=256 k=16 recall=1
# EVAL bits=2 nprobe=256 k=32 recall=1
#
#   EVAL lines: 6
# === test_search openai1536 4 ===
# File ../data/openai1536/openai1536_base.fvecs loaded
# Rows 100000 Cols 1536
# File ../data/openai1536/openai1536_query.fvecs loaded
# Rows 1000 Cols 1536
# File ../data/openai1536/openai1536_groundtruth.ivecs loaded
# Rows 1000 Cols 32
# data loaded
# 	N: 100000
# 	DIM: 1536
# query loaded
# 	NQ: 1000
# Loading IVF...
# 	Loading meta data...
# Allocating memory for IVF...
# Index loaded
# EVAL bits=4 nprobe=256 k=1 recall=0.974
# EVAL bits=4 nprobe=256 k=2 recall=1
# EVAL bits=4 nprobe=256 k=4 recall=1
# EVAL bits=4 nprobe=256 k=8 recall=1
# EVAL bits=4 nprobe=256 k=16 recall=1
# EVAL bits=4 nprobe=256 k=32 recall=1
#
#   EVAL lines: 6
# === test_search openai3072 2 ===
# File ../data/openai3072/openai3072_base.fvecs loaded
# Rows 100000 Cols 3072
# File ../data/openai3072/openai3072_query.fvecs loaded
# Rows 1000 Cols 3072
# File ../data/openai3072/openai3072_groundtruth.ivecs loaded
# Rows 1000 Cols 32
# data loaded
# 	N: 100000
# 	DIM: 3072
# query loaded
# 	NQ: 1000
# Loading IVF...
# 	Loading meta data...
# Allocating memory for IVF...
# Index loaded
# EVAL bits=2 nprobe=256 k=1 recall=0.932
# EVAL bits=2 nprobe=256 k=2 recall=0.987
# EVAL bits=2 nprobe=256 k=4 recall=1
# EVAL bits=2 nprobe=256 k=8 recall=1
# EVAL bits=2 nprobe=256 k=16 recall=1
# EVAL bits=2 nprobe=256 k=32 recall=1
#
#   EVAL lines: 6
# === test_search openai3072 4 ===
# File ../data/openai3072/openai3072_base.fvecs loaded
# Rows 100000 Cols 3072
# File ../data/openai3072/openai3072_query.fvecs loaded
# Rows 1000 Cols 3072
# File ../data/openai3072/openai3072_groundtruth.ivecs loaded
# Rows 1000 Cols 32
# data loaded
# 	N: 100000
# 	DIM: 3072
# query loaded
# 	NQ: 1000
# Loading IVF...
# 	Loading meta data...
# Allocating memory for IVF...
# Index loaded
# EVAL bits=4 nprobe=256 k=1 recall=0.986
# EVAL bits=4 nprobe=256 k=2 recall=1
# EVAL bits=4 nprobe=256 k=4 recall=1
# EVAL bits=4 nprobe=256 k=8 recall=1
# EVAL bits=4 nprobe=256 k=16 recall=1
# EVAL bits=4 nprobe=256 k=32 recall=1
#
#   EVAL lines: 6
# [6/7] Running PQ baselines
# [glove200_100k] running PQ baselines (metric=inner_product) ...
#   PQ-2bit: m=200, nbits=2, group=1 ... 343s
#   PQ-4bit: m=200, nbits=4, group=1 ... 399s
#   saved pq_results_glove200_100k.pkl
#     PQ-2bit: R@1=0.5110 R@2=0.6660 R@4=0.7998 R@8=0.8954 R@16=0.9512 R@32=0.9795
#     PQ-4bit: R@1=0.8066 R@2=0.9312 R@4=0.9824 R@8=0.9966 R@16=0.9992 R@32=0.9998
# [openai1536] running PQ baselines (metric=inner_product) ...
#   PQ-2bit: m=1536, nbits=2, group=1 ... 273s
#   PQ-4bit: m=1536, nbits=4, group=1 ... 319s
#   saved pq_results_openai1536.pkl
#     PQ-2bit: R@1=0.8640 R@2=0.9700 R@4=0.9960 R@8=1.0000 R@16=1.0000 R@32=1.0000
#     PQ-4bit: R@1=0.9420 R@2=0.9940 R@4=1.0000 R@8=1.0000 R@16=1.0000 R@32=1.0000
# [openai3072] running PQ baselines (metric=inner_product) ...
#   PQ-2bit: m=3072, nbits=2, group=1 ... 570s
#   PQ-4bit: m=3072, nbits=4, group=1 ... 682s
#   saved pq_results_openai3072.pkl
#     PQ-2bit: R@1=0.9140 R@2=0.9880 R@4=0.9990 R@8=1.0000 R@16=1.0000 R@32=1.0000
#     PQ-4bit: R@1=0.9680 R@2=0.9980 R@4=1.0000 R@8=1.0000 R@16=1.0000 R@32=1.0000
# [7/7] Plotting
#   saved /kaggle/working/reusableCodebook/results/figures/recall_glove200_100k.png
# [glove200_100k]
#   PQ-2bit (2 bits/dim)                     R@1=0.5110 R@2=0.6660 R@4=0.7998 R@8=0.8954 R@16=0.9512 R@32=0.9795
#   PQ-4bit (4 bits/dim)                     R@1=0.8066 R@2=0.9312 R@4=0.9824 R@8=0.9966 R@16=0.9992 R@32=0.9998
#   ExRaBitQ-2bit (2 bits/dim)               R@1=0.6529 R@2=0.8032 R@4=0.9071 R@8=0.9625 R@16=0.9875 R@32=0.9962
#   ExRaBitQ-4bit (4 bits/dim)               R@1=0.8803 R@2=0.9731 R@4=0.9966 R@8=0.9998 R@16=0.9999 R@32=0.9999
#   saved /kaggle/working/reusableCodebook/results/figures/recall_openai1536.png
# [openai1536]
#   PQ-2bit (2 bits/dim)                     R@1=0.8640 R@2=0.9700 R@4=0.9960 R@8=1.0000 R@16=1.0000 R@32=1.0000
#   PQ-4bit (4 bits/dim)                     R@1=0.9420 R@2=0.9940 R@4=1.0000 R@8=1.0000 R@16=1.0000 R@32=1.0000
#   ExRaBitQ-2bit (2 bits/dim)               R@1=0.8930 R@2=0.9840 R@4=0.9990 R@8=1.0000 R@16=1.0000 R@32=1.0000
#   ExRaBitQ-4bit (4 bits/dim)               R@1=0.9740 R@2=1.0000 R@4=1.0000 R@8=1.0000 R@16=1.0000 R@32=1.0000
#   saved /kaggle/working/reusableCodebook/results/figures/recall_openai3072.png
# [openai3072]
#   PQ-2bit (2 bits/dim)                     R@1=0.9140 R@2=0.9880 R@4=0.9990 R@8=1.0000 R@16=1.0000 R@32=1.0000
#   PQ-4bit (4 bits/dim)                     R@1=0.9680 R@2=0.9980 R@4=1.0000 R@8=1.0000 R@16=1.0000 R@32=1.0000
#   ExRaBitQ-2bit (2 bits/dim)               R@1=0.9320 R@2=0.9870 R@4=1.0000 R@8=1.0000 R@16=1.0000 R@32=1.0000
#   ExRaBitQ-4bit (4 bits/dim)               R@1=0.9860 R@2=1.0000 R@4=1.0000 R@8=1.0000 R@16=1.0000 R@32=1.0000
#   saved /kaggle/working/reusableCodebook/results/figures/recall_all_datasets.png
#
# figures in /kaggle/working/reusableCodebook/results/figures
#
# Done. Figures in: /kaggle/working/reusableCodebook/results/figures/
# total 408K
# -rw-r--r-- 1 root root 155K Apr 26 06:59 recall_all_datasets.png
# -rw-r--r-- 1 root root 103K Apr 26 06:59 recall_glove200_100k.png
# -rw-r--r-- 1 root root  76K Apr 26 06:59 recall_openai1536.png
# -rw-r--r-- 1 root root  71K Apr 26 06:59 recall_openai3072.png
